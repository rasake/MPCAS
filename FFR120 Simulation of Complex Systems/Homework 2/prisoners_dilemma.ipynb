# %% [markdown]
# # Homework 2: Evolutionary Game CA

# %%
# %matplotlib inline
import prisoners

# %% [markdown]
# ## Task 1 -- Basic game

# %% [markdown]
# ### 50 time steps

# %%
prisoners.demonstrate_basic_model(50,7)
# Out:
# Game settings:
# reward_pay_off = 1
# temptation_pay_off = 1.5
# sucker_pay_off = 0
# punishment_pay_off = 0.5

# %% [markdown]
# ### 1000 time steps

# %%
prisoners.demonstrate_basic_model(1000,7)
# Out:
# Game settings:
# reward_pay_off = 1
# temptation_pay_off = 1.5
# sucker_pay_off = 0
# punishment_pay_off = 0.5

# %% [markdown]
# ## Task2 --- Regimes

# %% [markdown]
# ### Regime 1
# Strategies that defect early dominate.

# %%
prisoners.demonstrate_regime1(50,7)
# Out:
# Game settings:
# reward_pay_off = 1
# temptation_pay_off = 1.5
# sucker_pay_off = 0
# punishment_pay_off = 0.8

# %% [markdown]
# ### Regime 2
# Mix of strategies with irregular oscillations.

# %%
prisoners.demonstrate_regime2(20,7)
# Out:
# Game settings:
# reward_pay_off = 1
# temptation_pay_off = 1.5
# sucker_pay_off = 0
# punishment_pay_off = 0.8

# %% [markdown]
# ### Regime 3
# Strategies that defect late in the game dominate.

# %%
prisoners.demonstrate_regime2(3,7)
# Out:
# Game settings:
# reward_pay_off = 1
# temptation_pay_off = 1.5
# sucker_pay_off = 0
# punishment_pay_off = 0.8

# %% [markdown]
# ## Task 3 -- Phase diagram
# One can observe three regions in the T,P-space corresponding to the tree different regimes.

# %%
prisoners.generate_regime_graph()
